# %% [markdown]
# # Coding Exercises (Part 9)

# %% [markdown]
# ## Pandas: Advanced Topics

# %% [markdown]
# ### Exercise 9: GroupBy Operations

# %%
#run the cell!
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use("seaborn")
pd.options.display.float_format = '{:.2f}'.format

# %%
#run the cell!
listings = pd.read_csv("listings_clean.csv")

# %%
#run the cell!
listings.head()
# Out:
#   Symbol Exchange                           Name  Last_Price     Market_Cap  \
# 0      A     NYSE     Agilent Technologies, Inc.       81.68 25934696179.92
# 1     AA     NYSE              Alcoa Corporation       29.15  5407809589.60
# 2   AABA   NASDAQ                    Altaba Inc.       75.39 42781131315.30
# 3    AAC     NYSE             AAC Holdings, Inc.        2.16    53141086.80
# 4    AAL   NASDAQ  American Airlines Group, Inc.       34.02 15276869742.96
#
#    IPO_Year            Sector  \
# 0      1999     Capital Goods
# 1      2016  Basic Industries
# 2      1969        Technology
# 3      2014       Health Care
# 4      1969    Transportation
#
#                                            Industry
# 0  Biotechnology: Laboratory Analytical Instruments
# 1                                          Aluminum
# 2                                      EDP Services
# 3                              Medical Specialities
# 4                     Air Freight/Delivery Services

# %%
#run the cell!
listings.tail()
# Out:
#      Symbol Exchange                           Name  Last_Price    Market_Cap  \
# 6847   ZUMZ   NASDAQ                    Zumiez Inc.       26.72  681919062.56
# 6848    ZUO     NYSE                    Zuora, Inc.       19.79 2147266454.00
# 6849   ZYME     NYSE                 Zymeworks Inc.       15.74  504078206.26
# 6850   ZYNE   NASDAQ  Zynerba Pharmaceuticals, Inc.        7.85  165399468.60
# 6851   ZYXI   NASDAQ                    Zynex, Inc.        5.02  161834880.48
#
#       IPO_Year             Sector  \
# 6847      2005  Consumer Services
# 6848      2018         Technology
# 6849      2017        Health Care
# 6850      2015        Health Care
# 6851      1969        Health Care
#
#                                                Industry
# 6847                     Clothing/Shoe/Accessory Stores
# 6848            Computer Software: Prepackaged Software
# 6849                              Major Pharmaceuticals
# 6850                              Major Pharmaceuticals
# 6851  Biotechnology: Electromedical & Electrotherape...

# %%
#run the cell!
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6852 entries, 0 to 6851
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Symbol      6852 non-null   object
#  1   Exchange    6852 non-null   object
#  2   Name        6852 non-null   object
#  3   Last_Price  6852 non-null   float64
#  4   Market_Cap  5954 non-null   float64
#  5   IPO_Year    6852 non-null   int64
#  6   Sector      5309 non-null   object
#  7   Industry    5309 non-null   object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 428.4+ KB

# %% [markdown]
# 83. __Group__ listings by the column __Exchange__ and __calculate__ the __mean__/average __Last_Price__ for each Exchange (mean price for nyse, for nasdaq and for amex)! <br>
# __Fill in the gaps!__ Which Exchange has, on average, the highest prices?

# %%
listings.head()
# Out:
#   Symbol Exchange                           Name  Last_Price     Market_Cap  \
# 0      A     NYSE     Agilent Technologies, Inc.       81.68 25934696179.92
# 1     AA     NYSE              Alcoa Corporation       29.15  5407809589.60
# 2   AABA   NASDAQ                    Altaba Inc.       75.39 42781131315.30
# 3    AAC     NYSE             AAC Holdings, Inc.        2.16    53141086.80
# 4    AAL   NASDAQ  American Airlines Group, Inc.       34.02 15276869742.96
#
#    IPO_Year            Sector  \
# 0      1999     Capital Goods
# 1      2016  Basic Industries
# 2      1969        Technology
# 3      2014       Health Care
# 4      1969    Transportation
#
#                                            Industry
# 0  Biotechnology: Laboratory Analytical Instruments
# 1                                          Aluminum
# 2                                      EDP Services
# 3                              Medical Specialities
# 4                     Air Freight/Delivery Services

# %%
listings.groupby("Exchange").Last_Price.mean()
# Out:
# Exchange
# AMEX     24.24
# NASDAQ   32.27
# NYSE     43.04
# Name: Last_Price, dtype: float64

# %% [markdown]
# The highest prices are ... on NYSE.

# %%
# need to use aggregate function after applying groupby method

# %%
listings.groupby("Exchange")

# %%
listings.groupby("Exchange").Last_Price

# %% [markdown]
# 84. __Group__ listings by the column __Sector__ and return the __highest/maximum Market_Cap__ that can be found on each Sector! <br> __Fill in the gaps__! What is the __Market Cap__ of the largest company in the Sector __Consumer Durables__ (divide by 1 Mio. to grasp large numbers!)?

# %%
listings.groupby("Sector").Market_Cap.max()
# Out:
# Sector
# Basic Industries        261790316546.85
# Capital Goods           206002047212.28
# Consumer Durables        41864347414.12
# Consumer Non-Durables   199393520886.56
# Consumer Services       907413834783.70
# Energy                  345390486272.36
# Finance                 342130105315.06
# Health Care             361018644165.18
# Miscellaneous           482638786997.02
# Public Utilities        242059300000.00
# Technology              945979473600.00
# Transportation          184992602793.45
# Name: Market_Cap, dtype: float64

# %% [markdown]
# The Market Cap is ... 41.86 billion US-Dollar

# %% [markdown]
# 85. __Count__ the __amount of listings__ per IPO_Year (hint: count __Symbols__) and __save__ the new DataFrame in the variable __listings_per_year__! __Fill in the gaps!__ <br>

# %%
listings.head()
# Out:
#   Symbol Exchange                           Name  Last_Price     Market_Cap  \
# 0      A     NYSE     Agilent Technologies, Inc.       81.68 25934696179.92
# 1     AA     NYSE              Alcoa Corporation       29.15  5407809589.60
# 2   AABA   NASDAQ                    Altaba Inc.       75.39 42781131315.30
# 3    AAC     NYSE             AAC Holdings, Inc.        2.16    53141086.80
# 4    AAL   NASDAQ  American Airlines Group, Inc.       34.02 15276869742.96
#
#    IPO_Year            Sector  \
# 0      1999     Capital Goods
# 1      2016  Basic Industries
# 2      1969        Technology
# 3      2014       Health Care
# 4      1969    Transportation
#
#                                            Industry
# 0  Biotechnology: Laboratory Analytical Instruments
# 1                                          Aluminum
# 2                                      EDP Services
# 3                              Medical Specialities
# 4                     Air Freight/Delivery Services

# %%
listings_per_year = listings.groupby("IPO_Year").Symbol.count()

# %%
# run the cell!
listings_per_year
# Out:
# IPO_Year
# 1969    3747
# 1972       2
# 1973       1
# 1980       2
# 1981       5
# 1982       2
# 1983      11
# 1984       3
# 1985       4
# 1986      36
# 1987      28
# 1988      18
# 1989      17
# 1990       9
# 1991      31
# 1992      61
# 1993      77
# 1994      48
# 1995      33
# 1996      55
# 1997      62
# 1998      40
# 1999      61
# 2000      43
# 2001      27
# 2002      62
# 2003      55
# 2004      95
# 2005      68
# 2006      68
# 2007      84
# 2008      11
# 2009      40
# 2010      84
# 2011      94
# 2012     110
# 2013     186
# 2014     272
# 2015     216
# 2016     195
# 2017     307
# 2018     396
# 2019      86
# Name: Symbol, dtype: int64

# %% [markdown]
# 86. Create a __lineplot__ for __listings_per_year__ (exclude 1969!)!

# %%
# df.plot will generate line plot by default
listings_per_year[1:].plot()
# Out:
# <AxesSubplot:xlabel='IPO_Year'>

# %% [markdown]
# 87. __Group__ listings by the columns __IPO_Year and Sector__ and count the number of listings per group (hint: count Symbol)!<br> __Save__ the resulting DataFrame in the variable __matrix__!

# %%
# matrix=listings.groupby(['IPO_Year','Sector']).Symbol.count()
matrix = listings.groupby(["IPO_Year", "Sector"]).Symbol.count()
matrix
# Out:
# IPO_Year  Sector
# 1969      Basic Industries         207
#           Capital Goods            236
#           Consumer Durables         89
#           Consumer Non-Durables    143
#           Consumer Services        409
#                                   ...
# 2019      Health Care               21
#           Miscellaneous              1
#           Public Utilities           2
#           Technology                 1
#           Transportation             1
# Name: Symbol, Length: 372, dtype: int64

# %%
# run the cell
matrix.head(20)
# Out:
# IPO_Year  Sector
# 1969      Basic Industries         207
#           Capital Goods            236
#           Consumer Durables         89
#           Consumer Non-Durables    143
#           Consumer Services        409
#           Energy                   151
#           Finance                  604
#           Health Care              348
#           Miscellaneous             72
#           Public Utilities         159
#           Technology               214
#           Transportation            60
# 1972      Consumer Non-Durables      1
#           Technology                 1
# 1973      Basic Industries           1
# 1980      Capital Goods              1
#           Technology                 1
# 1981      Capital Goods              1
#           Consumer Services          1
#           Finance                    1
# Name: Symbol, dtype: int64

# %% [markdown]
# 88. __Rearrange__ matrix by __unstacking Sector__! Use 0 (zero) as fill_value! __Fill in the gaps!__

# %%
matrix = matrix.unstack(fill_value=0)

# %%
# run the cell!
matrix.head()
# Out:
# Sector    Basic Industries  Capital Goods  Consumer Durables  \
# IPO_Year
# 1969                   207            236                 89
# 1972                     0              0                  0
# 1973                     1              0                  0
# 1980                     0              1                  0
# 1981                     0              1                  0
#
# Sector    Consumer Non-Durables  Consumer Services  Energy  Finance  \
# IPO_Year
# 1969                        143                409     151      604
# 1972                          1                  0       0        0
# 1973                          0                  0       0        0
# 1980                          0                  0       0        0
# 1981                          0                  1       0        1
#
# Sector    Health Care  Miscellaneous  Public Utilities  Technology  \
# IPO_Year
# 1969              348             72               159         214
# 1972                0              0                 0           1
# 1973                0              0                 0           0
# 1980                0              0                 0           1
# 1981                2              0                 0           0
#
# Sector    Transportation
# IPO_Year
# 1969                  60
# 1972                   0
# 1973                   0
# 1980                   0
# 1981                   0

# %% [markdown]
# 89. __Select__ all rows/listings with __IPO_Year__ from 1990 (incl.) till today and __save__ the new DataFrame in the variable __matrix1__!

# %%
matrix1=matrix.loc[1990:]

# %%
# run the cell!
matrix1
# Out:
# Sector    Basic Industries  Capital Goods  Consumer Durables  \
# IPO_Year
# 1990                     1              1                  0
# 1991                     0              2                  1
# 1992                     2              4                  0
# 1993                     3              8                  4
# 1994                     5              5                  2
# 1995                     1              4                  1
# 1996                     5              3                  1
# 1997                     1              8                  5
# 1998                     0              2                  1
# 1999                     0              5                  0
# 2000                     0              7                  1
# 2001                     1              0                  0
# 2002                     1              0                  1
# 2003                     1              0                  1
# 2004                     3              4                  1
# 2005                     3              2                  1
# 2006                     2              8                  2
# 2007                     1              3                  0
# 2008                     2              1                  0
# 2009                     1              0                  1
# 2010                     4              7                  1
# 2011                     5              5                  0
# 2012                     4              6                  1
# 2013                     5             11                  3
# 2014                    11             11                  2
# 2015                    11             10                  4
# 2016                    11              5                  1
# 2017                    11              8                  8
# 2018                     9             12                  3
# 2019                     1              0                  0
#
# Sector    Consumer Non-Durables  Consumer Services  Energy  Finance  \
# IPO_Year
# 1990                          0                  0       1        0
# 1991                          1                  6       0        4
# 1992                          1                  9       1        4
# 1993                          6                 18       2        2
# 1994                          1                 11       1        2
# 1995                          3                  7       2        2
# 1996                          7                  8       1        3
# 1997                          3                  9       2        4
# 1998                          2                  2       1        4
# 1999                          2                  7       3        5
# 2000                          1                  3       1        2
# 2001                          2                  1       2        3
# 2002                          0                  9       3        3
# 2003                          1                  6       1        9
# 2004                          2                 14       2        8
# 2005                          2                 10       3        8
# 2006                          3                 10       2        3
# 2007                          1                 13       6        7
# 2008                          0                  3       0        0
# 2009                          1                  9       1        3
# 2010                          3                 10       2       10
# 2011                          4                 12      14        5
# 2012                          3                 17      11       11
# 2013                          4                 44       6       18
# 2014                          2                 42      13       34
# 2015                          5                 33       2       22
# 2016                         11                 16      12       21
# 2017                          7                 45      30       64
# 2018                          8                 29      13      139
# 2019                          1                  3       1       44
#
# Sector    Health Care  Miscellaneous  Public Utilities  Technology  \
# IPO_Year
# 1990                1              0                 0           2
# 1991                5              0                 0           4
# 1992                8              2                 0           6
# 1993                1              0                 0          10
# 1994                3              1                 4           9
# 1995                2              0                 1          10
# 1996                6              0                 1          18
# 1997                7              1                 3          12
# 1998                4              3                 1           9
# 1999                2              7                 3          17
# 2000               14              1                 0          13
# 2001                4              2                 0           4
# 2002                0              0                 2           5
# 2003                1              1                 1           2
# 2004               14              2                 2           7
# 2005                7              3                 1           3
# 2006                9              6                 1           8
# 2007                7              5                 6          10
# 2008                1              0                 1           2
# 2009                5              0                 0           7
# 2010                5              3                 2          15
# 2011                8              3                 3          15
# 2012               10              2                 3          16
# 2013               38              2                 5          21
# 2014               82              7                13          32
# 2015               76              6                 8          23
# 2016               44              7                25          26
# 2017               60              4                 7          30
# 2018               88              9                 8          47
# 2019               21              1                 2           1
#
# Sector    Transportation
# IPO_Year
# 1990                   0
# 1991                   1
# 1992                   1
# 1993                   1
# 1994                   1
# 1995                   0
# 1996                   2
# 1997                   4
# 1998                   0
# 1999                   1
# 2000                   0
# 2001                   0
# 2002                   2
# 2003                   0
# 2004                   1
# 2005                   6
# 2006                   4
# 2007                   2
# 2008                   1
# 2009                   1
# 2010                   3
# 2011                   0
# 2012                   0
# 2013                   5
# 2014                   6
# 2015                   2
# 2016                   2
# 2017                   8
# 2018                   3
# 2019                   1

# %% [markdown]
# Congrats, you created the DataFrame matrix1 that we visualized in Exercise 7 with a Seaborn Heatmap!

# %%
# run and see again!
import seaborn as sns

plt.figure(figsize=(12,8))
sns.set(font_scale=1.0)
sns.heatmap(matrix1, cmap = "viridis", vmax = 25)
plt.show()

# %% [markdown]
# # Recap

# %% [markdown]
# 83. do statistics based on groups
#
# `df.groupby('Col1').Col2.mean()`

# %% [markdown]
# 88. rearrange the __grouped__ dataframe with the __innermost__ index
#
# `df.unstack(fill_value=)`
