# %% [markdown]
# # Coding Exercises (Part 8)

# %% [markdown]
# Now, you will have the opportunity to analyze your own dataset. <br>
# __Follow the instructions__ and insert your code! You are either requested to
# - Complete the Code and __Fill in the gaps__. Gaps are marked with "__---__" and are __placeholders__ for your code fragment
# - Write Code completely __on your own__

# %% [markdown]
# In some exercises, you will find questions that can only be answered, if your code is correct and returns the right output! The correct answer is provided below your coding cell. There you can check whether your code is correct.

# %% [markdown]
# If you need a hint, check the __Hints Section__ at the end of this Notebook. Exercises and Hints are numerated accordingly.

# %% [markdown]
# If you need some further help or if you want to check your code, you can also watch the __solutions videos__ or check the __solutions notebook__.

# %% [markdown]
# ### Have Fun!

# %% [markdown]
# --------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ## Pandas: Advanced Topics

# %% [markdown]
# ### Exercise 8: Creating and Removing Rows and Columns

# %%
#run the cell!
import pandas as pd
pd.options.display.float_format = '{:.2f}'.format

# %%
#run the cell!
listings = pd.read_csv("listings_clean.csv")

# %%
#run the cell!
listings.head()
# Out:
#   Symbol Exchange                           Name  Last_Price     Market_Cap  \
# 0      A     NYSE     Agilent Technologies, Inc.       81.68 25934696179.92
# 1     AA     NYSE              Alcoa Corporation       29.15  5407809589.60
# 2   AABA   NASDAQ                    Altaba Inc.       75.39 42781131315.30
# 3    AAC     NYSE             AAC Holdings, Inc.        2.16    53141086.80
# 4    AAL   NASDAQ  American Airlines Group, Inc.       34.02 15276869742.96
#
#    IPO_Year            Sector  \
# 0      1999     Capital Goods
# 1      2016  Basic Industries
# 2      1969        Technology
# 3      2014       Health Care
# 4      1969    Transportation
#
#                                            Industry
# 0  Biotechnology: Laboratory Analytical Instruments
# 1                                          Aluminum
# 2                                      EDP Services
# 3                              Medical Specialities
# 4                     Air Freight/Delivery Services

# %%
# run the cell!
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6852 entries, 0 to 6851
# Data columns (total 8 columns):
# Symbol        6852 non-null object
# Exchange      6852 non-null object
# Name          6852 non-null object
# Last_Price    6852 non-null float64
# Market_Cap    5954 non-null float64
# IPO_Year      6852 non-null int64
# Sector        5309 non-null object
# Industry      5309 non-null object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 428.3+ KB

# %% [markdown]
# 76. __Drop__ the columns __"Symbol"__ and __"Sector"__ from the DataFrame listings! __Save__ the change! __Fill in the gaps!__

# %%
listings.drop(columns = ["Symbol", "Sector"], inplace = True)

# %%
# run the cell!
listings.head()
# Out:
#   Exchange                           Name  Last_Price     Market_Cap  \
# 0     NYSE     Agilent Technologies, Inc.       81.68 25934696179.92
# 1     NYSE              Alcoa Corporation       29.15  5407809589.60
# 2   NASDAQ                    Altaba Inc.       75.39 42781131315.30
# 3     NYSE             AAC Holdings, Inc.        2.16    53141086.80
# 4   NASDAQ  American Airlines Group, Inc.       34.02 15276869742.96
#
#    IPO_Year                                          Industry
# 0      1999  Biotechnology: Laboratory Analytical Instruments
# 1      2016                                          Aluminum
# 2      1969                                      EDP Services
# 3      2014                              Medical Specialities
# 4      1969                     Air Freight/Delivery Services

# %% [markdown]
# 77. __Drop__ all rows/listings on __"AMEX"__ from the DataFrame listings! Use the __loc__ operator and __overwrite listings__!<br> __Fill in the gaps!__

# %%
listings = listings.loc[listings.Exchange != "AMEX"]

# %%
# run the cell!
listings.head()
# Out:
#   Exchange                           Name  Last_Price     Market_Cap  \
# 0     NYSE     Agilent Technologies, Inc.       81.68 25934696179.92
# 1     NYSE              Alcoa Corporation       29.15  5407809589.60
# 2   NASDAQ                    Altaba Inc.       75.39 42781131315.30
# 3     NYSE             AAC Holdings, Inc.        2.16    53141086.80
# 4   NASDAQ  American Airlines Group, Inc.       34.02 15276869742.96
#
#    IPO_Year                                          Industry
# 0      1999  Biotechnology: Laboratory Analytical Instruments
# 1      2016                                          Aluminum
# 2      1969                                      EDP Services
# 3      2014                              Medical Specialities
# 4      1969                     Air Freight/Delivery Services

# %%
# run the cell!
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6541 entries, 0 to 6851
# Data columns (total 6 columns):
# Exchange      6541 non-null object
# Name          6541 non-null object
# Last_Price    6541 non-null float64
# Market_Cap    5677 non-null float64
# IPO_Year      6541 non-null int64
# Industry      5085 non-null object
# dtypes: float64(2), int64(1), object(3)
# memory usage: 357.7+ KB

# %% [markdown]
# 78. __Add__ the new column __MCAP_MUSD__ (Market Cap in Million USD) to the DataFrame listings by dividing Market_Cap by 1 million. __Fill in the gaps__!

# %%
listings["MCAP_MUSD"] = listings.Market_Cap/1000000

# %% [markdown]
# __Inspect__! What is the __MCAP_MUSD__ for AAC Holdings?

# %%
# run the cell!
listings.head()
# Out:
#   Exchange                           Name  Last_Price     Market_Cap  \
# 0     NYSE     Agilent Technologies, Inc.       81.68 25934696179.92
# 1     NYSE              Alcoa Corporation       29.15  5407809589.60
# 2   NASDAQ                    Altaba Inc.       75.39 42781131315.30
# 3     NYSE             AAC Holdings, Inc.        2.16    53141086.80
# 4   NASDAQ  American Airlines Group, Inc.       34.02 15276869742.96
#
#    IPO_Year                                          Industry  MCAP_MUSD
# 0      1999  Biotechnology: Laboratory Analytical Instruments   25934.70
# 1      2016                                          Aluminum    5407.81
# 2      1969                                      EDP Services   42781.13
# 3      2014                              Medical Specialities      53.14
# 4      1969                     Air Freight/Delivery Services   15276.87

# %% [markdown]
# AAC Holdings has a Market Cap of ... 53.14 MUSD!

# %% [markdown]
# 79. __Add__ the new column __Shares__ with the total amount of __shares outstanding__ for each listing. __Divide__ __Market_Cap__ by the __Last_Price__! <br>
# Instead of using the arithmetic sign "/", use an __appropriate method for division__!

# %%
listings["Shares"] = listings.Market_Cap.div(listings.Last_Price)

# %%
# run the cell!
listings.head()
# Out:
#   Exchange                           Name  Last_Price     Market_Cap  \
# 0     NYSE     Agilent Technologies, Inc.       81.68 25934696179.92
# 1     NYSE              Alcoa Corporation       29.15  5407809589.60
# 2   NASDAQ                    Altaba Inc.       75.39 42781131315.30
# 3     NYSE             AAC Holdings, Inc.        2.16    53141086.80
# 4   NASDAQ  American Airlines Group, Inc.       34.02 15276869742.96
#
#    IPO_Year                                          Industry  MCAP_MUSD  \
# 0      1999  Biotechnology: Laboratory Analytical Instruments   25934.70
# 1      2016                                          Aluminum    5407.81
# 2      1969                                      EDP Services   42781.13
# 3      2014                              Medical Specialities      53.14
# 4      1969                     Air Freight/Delivery Services   15276.87
#
#         Shares
# 0 317515869.00
# 1 185516624.00
# 2 567464270.00
# 3  24602355.00
# 4 449055548.00

# %%
# run the cell!
listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6541 entries, 0 to 6851
# Data columns (total 8 columns):
# Exchange      6541 non-null object
# Name          6541 non-null object
# Last_Price    6541 non-null float64
# Market_Cap    5677 non-null float64
# IPO_Year      6541 non-null int64
# Industry      5085 non-null object
# MCAP_MUSD     5677 non-null float64
# Shares        5583 non-null float64
# dtypes: float64(4), int64(1), object(3)
# memory usage: 459.9+ KB

# %% [markdown]
# 80. __Sort__ listings by the __Shares__ column from __high to low__. Which listing has the __largest number__ of shares outstanding

# %%
listings.sort_values(by = "Shares", ascending= False)
# Out:
#      Exchange                                             Name  Last_Price  \
# 3812     NYSE                         Lloyds Banking Group Plc        3.28
# 5422     NYSE                            Banco Santander, S.A.        4.91
# 25       NYSE                                       Ambev S.A.        4.54
# 4169     NYSE               Mitsubishi UFJ Financial Group Inc        5.04
# 3929     NYSE                     Mizuho Financial Group, Inc.        3.12
# 3349     NYSE                   Itau Unibanco Banco Holding SA        8.90
# 656      NYSE                                Banco Bradesco Sa        9.34
# 625      NYSE                      Bank of America Corporation       29.07
# 2610     NYSE                         General Electric Company        9.16
# 4109   NASDAQ                            Microsoft Corporation      120.19
# 938      NYSE                        Banco Santander Brasil SA       11.76
# 5916     NYSE                                        AT&T Inc.       31.88
# 5645     NYSE              Sumitomo Mitsui Financial Group Inc        7.14
# 658      NYSE                                Banco Bradesco Sa        8.18
# 674      NYSE             Banco Bilbao Viscaya Argentaria S.A.        6.01
# 4746     NYSE              Petroleo Brasileiro S.A.- Petrobras       16.99
# 5182     NYSE                    Royal Bank Scotland plc (The)        6.76
# 6661     NYSE                                    Wipro Limited        4.30
# 3667     NYSE             China Life Insurance Company Limited       13.73
# 4404     NYSE                                Nokia Corporation        5.85
# 4827     NYSE                                     Pfizer, Inc.       42.73
# 6004     NYSE                                    Telefonica SA        8.35
# 6207     NYSE  Taiwan Semiconductor Manufacturing Company Ltd.       42.37
# 6414     NYSE                                        VALE S.A.       13.56
# 5593   NASDAQ                          Sirius XM Holdings Inc.        5.99
# 11     NASDAQ                                       Apple Inc.      200.62
# 6626     NYSE                            Wells Fargo & Company       47.79
# 1354   NASDAQ                              Comcast Corporation       41.08
# 3265   NASDAQ                                Intel Corporation       55.75
# 1537   NASDAQ                              Cisco Systems, Inc.       55.82
# ...       ...                                              ...         ...
# 6630     NYSE                            Wells Fargo & Company       24.55
# 6631     NYSE                            Wells Fargo & Company       26.00
# 6632     NYSE                            Wells Fargo & Company       27.81
# 6633     NYSE                            Wells Fargo & Company       25.59
# 6634     NYSE                            Wells Fargo & Company       26.10
# 6635     NYSE                            Wells Fargo & Company       25.45
# 6636     NYSE                            Wells Fargo & Company       25.27
# 6637     NYSE                            Wells Fargo & Company       25.49
# 6638     NYSE                            Wells Fargo & Company       25.67
# 6644   NASDAQ                         WhiteHorse Finance, Inc.       25.84
# 6650   NASDAQ       Wheeler Real Estate Investment Trust, Inc.        0.01
# 6656   NASDAQ          Western Asset Short Duration Income ETF       25.45
# 6690     NYSE                      Washington Prime Group Inc.       21.54
# 6691     NYSE                      Washington Prime Group Inc.       19.82
# 6697     NYSE                         W.R. Berkley Corporation       25.25
# 6698     NYSE                         W.R. Berkley Corporation       25.74
# 6699     NYSE                         W.R. Berkley Corporation       25.17
# 6700     NYSE                         W.R. Berkley Corporation       25.27
# 6706   NASDAQ                        Pensare Acquisition Corp.        0.28
# 6707   NASDAQ                        Pensare Acquisition Corp.       10.50
# 6708   NASDAQ                        Pensare Acquisition Corp.        0.18
# 6717     NYSE                                     Watsco, Inc.        0.00
# 6751     NYSE                            Exantas Capital Corp.       25.85
# 6816     NYSE                        Zions Bancorporation N.A.       29.07
# 6818     NYSE                        Zions Bancorporation N.A.       23.70
# 6819     NYSE                        Zions Bancorporation N.A.       27.62
# 6820     NYSE                        Zions Bancorporation N.A.       25.55
# 6830   NASDAQ                        Zions Bancorporation N.A.       14.74
# 6839   NASDAQ                               Zion Oil & Gas Inc        0.00
# 6843   NASDAQ                                BATS BZX Exchange       10.10
#
#           Market_Cap  IPO_Year  \
# 3812  58377889642.08      1969
# 5422  79721578055.22      1969
# 25    71397713602.90      2013
# 4169  65129451176.16      1969
# 3929  39558969655.92      1969
# 3349  86524648945.20      1969
# 656   90379475746.66      1969
# 625  280204178999.22      1969
# 2610  79780283328.88      1969
# 4109 922123334074.74      1986
# 938   87869508720.00      2009
# 5916 232412752595.16      1969
# 5645  49822872733.20      1969
# 658   54968439217.10      1969
# 674   40073998345.80      1969
# 4746 110813001420.35      1969
# 5182  40864362976.84      1969
# 6661  25853045617.00      1969
# 3667  77614893660.00      2003
# 4404  32713382052.00      1994
# 4827 237228618676.70      1969
# 6004  43354299578.10      1988
# 6207 219734040120.00      1997
# 6414  69512063876.88      1969
# 5593  28372142916.06      1969
# 11   945979473600.00      1980
# 6626 217059877477.80      1969
# 1354 185926540403.76      1969
# 3265 250800765641.50      1969
# 1537 245721187107.12      1990
# ...              ...       ...
# 6630             nan      1969
# 6631             nan      1969
# 6632             nan      1969
# 6633             nan      1969
# 6634             nan      1969
# 6635             nan      1969
# 6636             nan      1969
# 6637             nan      1969
# 6638             nan      1969
# 6644             nan      1969
# 6650             nan      1969
# 6656             nan      1969
# 6690             nan      1969
# 6691             nan      1969
# 6697             nan      1969
# 6698             nan      1969
# 6699             nan      1969
# 6700             nan      1969
# 6706             nan      2017
# 6707             nan      2017
# 6708             nan      2017
# 6717            0.00      1969
# 6751             nan      1969
# 6816             nan      1969
# 6818             nan      1969
# 6819             nan      1969
# 6820             nan      1969
# 6830             nan      1969
# 6839            0.00      1969
# 6843             nan      1969
#
#                                                Industry  MCAP_MUSD  \
# 3812                                   Commercial Banks   58377.89
# 5422                                   Commercial Banks   79721.58
# 25                  Beverages (Production/Distribution)   71397.71
# 4169                                   Commercial Banks   65129.45
# 3929                                        Major Banks   39558.97
# 3349                                        Major Banks   86524.65
# 656                                         Major Banks   90379.48
# 625                                         Major Banks  280204.18
# 2610                    Consumer Electronics/Appliances   79780.28
# 4109            Computer Software: Prepackaged Software  922123.33
# 938                                    Commercial Banks   87869.51
# 5916                       Telecommunications Equipment  232412.75
# 5645                                   Commercial Banks   49822.87
# 658                                         Major Banks   54968.44
# 674                                    Commercial Banks   40074.00
# 4746                               Oil & Gas Production  110813.00
# 5182                                   Commercial Banks   40864.36
# 6661                                       EDP Services   25853.05
# 3667                                     Life Insurance   77614.89
# 4404  Radio And Television Broadcasting And Communic...   32713.38
# 4827                              Major Pharmaceuticals  237228.62
# 6004                       Telecommunications Equipment   43354.30
# 6207                                     Semiconductors  219734.04
# 6414                                    Precious Metals   69512.06
# 5593                                       Broadcasting   28372.14
# 11                               Computer Manufacturing  945979.47
# 6626                                        Major Banks  217059.88
# 1354                                Television Services  185926.54
# 3265                                     Semiconductors  250800.77
# 1537                  Computer Communications Equipment  245721.19
# ...                                                 ...        ...
# 6630                                                NaN        nan
# 6631                                                NaN        nan
# 6632                                                NaN        nan
# 6633                                                NaN        nan
# 6634                                                NaN        nan
# 6635                                                NaN        nan
# 6636                                                NaN        nan
# 6637                                                NaN        nan
# 6638                                                NaN        nan
# 6644                                                NaN        nan
# 6650                      Real Estate Investment Trusts        nan
# 6656                                                NaN        nan
# 6690                                                NaN        nan
# 6691                                                NaN        nan
# 6697                                                NaN        nan
# 6698                                                NaN        nan
# 6699                                                NaN        nan
# 6700                                                NaN        nan
# 6706                                  Business Services        nan
# 6707                                  Business Services        nan
# 6708                                  Business Services        nan
# 6717                                                NaN       0.00
# 6751                                                NaN        nan
# 6816                                        Major Banks        nan
# 6818                                                NaN        nan
# 6819                                                NaN        nan
# 6820                                                NaN        nan
# 6830                                        Major Banks        nan
# 6839                               Oil & Gas Production       0.00
# 6843                                                NaN        nan
#
#              Shares
# 3812 17798137086.00
# 5422 16236573942.00
# 25   15726368635.00
# 4169 12922510154.00
# 3929 12679156941.00
# 3349  9721870668.00
# 656   9676603399.00
# 625   9638946646.00
# 2610  8709637918.00
# 4109  7672213446.00
# 938   7471897000.00
# 5916  7290236907.00
# 5645  6977993380.00
# 658   6719858095.00
# 674   6667886580.00
# 4746  6522248465.00
# 5182  6045024109.00
# 6661  6012336190.00
# 3667  5652942000.00
# 4404  5592031120.00
# 4827  5551804790.00
# 6004  5192131686.00
# 6207  5186076000.00
# 6414  5126258398.00
# 5593  4736584794.00
# 11    4715280000.00
# 6626  4541951820.00
# 1354  4525962522.00
# 3265  4498668442.00
# 1537  4402027716.00
# ...             ...
# 6630            nan
# 6631            nan
# 6632            nan
# 6633            nan
# 6634            nan
# 6635            nan
# 6636            nan
# 6637            nan
# 6638            nan
# 6644            nan
# 6650            nan
# 6656            nan
# 6690            nan
# 6691            nan
# 6697            nan
# 6698            nan
# 6699            nan
# 6700            nan
# 6706            nan
# 6707            nan
# 6708            nan
# 6717            nan
# 6751            nan
# 6816            nan
# 6818            nan
# 6819            nan
# 6820            nan
# 6830            nan
# 6839            nan
# 6843            nan
#
# [6541 rows x 8 columns]

# %% [markdown]
# Lloyds Banking Group has over 17 billion shares outstanding!

# %% [markdown]
# 81. Let´s assume we have the listings for NYSE, NASDAQ and AMEX in __three separate datasets__. __Import__ the three datasets into Pandas and __inspect__!

# %%
# run the cell!
nyse = pd.read_csv("NYSE.csv")
nasdaq = pd.read_csv("NASDAQ.csv") 
amex = pd.read_csv("AMEX.csv")

# %%
# run the cell!
nyse.head()
# Out:
#   Symbol                    Name  LastSale       MarketCap  ADR TSO  IPOyear  \
# 0    DDD  3D Systems Corporation     10.91   1272949528.47      nan      nan
# 1    MMM              3M Company    212.11 122153435461.96      nan      nan
# 2   WBAI         500.com Limited     13.85    588423939.55      nan  2013.00
# 3   WUBA             58.com Inc.     70.11  10391864681.79      nan  2013.00
# 4   EGHT                 8x8 Inc     21.09   2017357580.82      nan      nan
#
#               Sector                                         Industry
# 0         Technology          Computer Software: Prepackaged Software
# 1        Health Care                       Medical/Dental Instruments
# 2  Consumer Services            Services-Misc. Amusement & Recreation
# 3         Technology  Computer Software: Programming, Data Processing
# 4         Technology                                     EDP Services

# %%
# run the cell!
nyse.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3106 entries, 0 to 3105
# Data columns (total 8 columns):
# Symbol       3106 non-null object
# Name         3106 non-null object
# LastSale     3015 non-null float64
# MarketCap    3106 non-null float64
# ADR TSO      0 non-null float64
# IPOyear      1416 non-null float64
# Sector       2121 non-null object
# Industry     2121 non-null object
# dtypes: float64(4), object(4)
# memory usage: 194.2+ KB

# %%
# run the cell!
nasdaq.head()
# Out:
#   Symbol                                    Name  LastSale     MarketCap  \
# 0     YI                               111, Inc.      7.10   56690340.50
# 1    PIH  1347 Property Insurance Holdings, Inc.      5.20   31266372.80
# 2  PIHPP  1347 Property Insurance Holdings, Inc.     24.90   17430000.00
# 3   TURN                180 Degree Capital Corp.      1.91   59286575.61
# 4   FLWS                 1-800 FLOWERS.COM, Inc.     18.81 1206817397.28
#
#      ADR TSO  IPOyear             Sector                    Industry
# 0 7984555.00  2018.00        Health Care    Medical/Nursing Services
# 1        nan  2014.00            Finance  Property-Casualty Insurers
# 2        nan      nan            Finance  Property-Casualty Insurers
# 3        nan      nan            Finance  Finance/Investors Services
# 4        nan  1999.00  Consumer Services      Other Specialty Stores

# %%
# run the cell!
nasdaq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3435 entries, 0 to 3434
# Data columns (total 8 columns):
# Symbol       3435 non-null object
# Name         3435 non-null object
# LastSale     3432 non-null float64
# MarketCap    3435 non-null float64
# ADR TSO      140 non-null float64
# IPOyear      1599 non-null float64
# Sector       2964 non-null object
# Industry     2964 non-null object
# dtypes: float64(4), object(4)
# memory usage: 214.8+ KB

# %%
# run the cell!
amex.head()
# Out:
#   Symbol                                               Name  LastSale  \
# 0   XXII                            22nd Century Group, Inc      1.89
# 1    FAX              Aberdeen Asia-Pacific Income Fund Inc      4.14
# 2    IAF                 Aberdeen Australia Equity Fund Inc      5.45
# 3    AEF  Aberdeen Emerging Markets Equity Income Fund, ...      7.58
# 4    FCO                  Aberdeen Global Income Fund, Inc.      8.16
#
#       MarketCap  ADR TSO  IPOyear                 Sector  \
# 0  235574500.77      nan      nan  Consumer Non-Durables
# 1 1042993611.36      nan  1986.00                    NaN
# 2  123945676.70      nan      nan                    NaN
# 3  453154667.63      nan      nan                    NaN
# 4   71194278.24      nan  1992.00                    NaN
#
#                 Industry
# 0  Farming/Seeds/Milling
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
# run the cell!
amex.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 8 columns):
# Symbol       311 non-null object
# Name         311 non-null object
# LastSale     298 non-null float64
# MarketCap    311 non-null float64
# ADR TSO      0 non-null float64
# IPOyear      90 non-null float64
# Sector       224 non-null object
# Industry     224 non-null object
# dtypes: float64(4), object(4)
# memory usage: 19.5+ KB

# %% [markdown]
# 82. __Concatenate__ the three DataFrames into one DataFrame and save the new DataFrame in the variable __all_listings__! <br>
# Each row/listing should contain information about the respective __Exchange__ (__NYSE__, __NASDAQ__ or __AMEX__)! __Fill in the gaps__!

# %%
all_listings = pd.concat([nyse, nasdaq, amex], keys = ["NYSE", "NASDAQ", "AMEX"], names = ["Exchange"])

# %%
# run the cell!
all_listings.head()
# Out:
#            Symbol                    Name  LastSale       MarketCap  ADR TSO  \
# Exchange
# NYSE     0    DDD  3D Systems Corporation     10.91   1272949528.47      nan
#          1    MMM              3M Company    212.11 122153435461.96      nan
#          2   WBAI         500.com Limited     13.85    588423939.55      nan
#          3   WUBA             58.com Inc.     70.11  10391864681.79      nan
#          4   EGHT                 8x8 Inc     21.09   2017357580.82      nan
#
#             IPOyear             Sector  \
# Exchange
# NYSE     0      nan         Technology
#          1      nan        Health Care
#          2  2013.00  Consumer Services
#          3  2013.00         Technology
#          4      nan         Technology
#
#                                                    Industry
# Exchange
# NYSE     0          Computer Software: Prepackaged Software
#          1                       Medical/Dental Instruments
#          2            Services-Misc. Amusement & Recreation
#          3  Computer Software: Programming, Data Processing
#          4                                     EDP Services

# %%
# run the cell to tidy up!
all_listings = all_listings.reset_index().drop(columns = "level_1")

# %% [markdown]
# How many listings does __listings_all__ contain in total?

# %%
# run and inspect!
all_listings.head()
# Out:
#   Exchange Symbol                    Name  LastSale       MarketCap  ADR TSO  \
# 0     NYSE    DDD  3D Systems Corporation     10.91   1272949528.47      nan
# 1     NYSE    MMM              3M Company    212.11 122153435461.96      nan
# 2     NYSE   WBAI         500.com Limited     13.85    588423939.55      nan
# 3     NYSE   WUBA             58.com Inc.     70.11  10391864681.79      nan
# 4     NYSE   EGHT                 8x8 Inc     21.09   2017357580.82      nan
#
#    IPOyear             Sector                                         Industry
# 0      nan         Technology          Computer Software: Prepackaged Software
# 1      nan        Health Care                       Medical/Dental Instruments
# 2  2013.00  Consumer Services            Services-Misc. Amusement & Recreation
# 3  2013.00         Technology  Computer Software: Programming, Data Processing
# 4      nan         Technology                                     EDP Services

# %%
# run and inspect!
all_listings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6852 entries, 0 to 6851
# Data columns (total 9 columns):
# Exchange     6852 non-null object
# Symbol       6852 non-null object
# Name         6852 non-null object
# LastSale     6745 non-null float64
# MarketCap    6852 non-null float64
# ADR TSO      140 non-null float64
# IPOyear      3105 non-null float64
# Sector       5309 non-null object
# Industry     5309 non-null object
# dtypes: float64(4), object(5)
# memory usage: 481.9+ KB

# %% [markdown]
# There are in total ... 6852 listings!

# %% [markdown]
# # Well Done!

# %% [markdown]
# ---------------------------------

# %% [markdown]
# # Hints (Spoiler!)

# %% [markdown]
# 76. drop() method, columns parameter

# %% [markdown]
# 77. listings.Exchange != "AMEX"

# %% [markdown]
# 78. pass "MCAP_MUSD" as new column label, Market_Cap column

# %% [markdown]
# 79. use the div() method -> listings[---] = listings.---.div(listings.---)

# %% [markdown]
# 80. sort_values() method

# %% [markdown]
# 81. run the cells and inspects!

# %% [markdown]
# 82. pd.concat() method, keys parameter
