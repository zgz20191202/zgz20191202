# %% [markdown]
# **1. Cannot display Chinese in Matplotlib with MacOS:**

# %% [markdown]
# The reason is MacOS does not have sans-serif
#
# so we need to choose fonts supporting Chinese

# %%
from matplotlib import font_manager

ttf_lists = font_manager.fontManager.ttflist
for font in ttf_lists:
    print(font)
# Out:
# <Font 'STIXNonUnicode' (STIXNonUniBol.ttf) normal normal 700 normal>
# <Font 'DejaVu Sans Mono' (DejaVuSansMono-BoldOblique.ttf) oblique normal 700 normal>
# <Font 'DejaVu Serif' (DejaVuSerif-Italic.ttf) italic normal 400 normal>
# <Font 'STIXSizeFiveSym' (STIXSizFiveSymReg.ttf) normal normal 400 normal>
# <Font 'STIXSizeTwoSym' (STIXSizTwoSymReg.ttf) normal normal 400 normal>
# <Font 'DejaVu Sans' (DejaVuSans-BoldOblique.ttf) oblique normal 700 normal>
# <Font 'DejaVu Serif' (DejaVuSerif.ttf) normal normal 400 normal>
# <Font 'DejaVu Sans' (DejaVuSans.ttf) normal normal 400 normal>
# <Font 'cmb10' (cmb10.ttf) normal normal 400 normal>
# <Font 'cmss10' (cmss10.ttf) normal normal 400 normal>
# <Font 'DejaVu Sans' (DejaVuSans-Bold.ttf) normal normal 700 normal>
# <Font 'STIXGeneral' (STIXGeneral.ttf) normal normal 400 normal>
# <Font 'STIXNonUnicode' (STIXNonUni.ttf) normal normal 400 normal>
# <Font 'cmr10' (cmr10.ttf) normal normal 400 normal>
# ...

# %%
# Solve PyPlot Chinese Language Problem
plt.rcParams['font.sans-serif'] = ['Songti SC']

# %% [markdown]
# ---

# %% [markdown]
# **2. how draw effective frontier?**

# %% [markdown]
# 1. generate 100 (as many as possible) mean of return
#
# 2. use scipy.opimize.minimize to get min volatility of portfolio given mean

# %% [markdown]
# ---

# %% [markdown]
# **3. how draw CML?**

# %% [markdown]
# A CML is a line connecting risk-free point and an attainable portfolio with max sharp ratio
#
# I use scipy.optimize to get the max sharp ratio.
#
# Then deduct volatility based on max sharp ratio and mean

# %% [markdown]
# ---

# %% [markdown]
# **4. how to create a CAPM Model?**

# %% [markdown]
# use market index as market return
#
# pick a security
#
# Conduct linear regression between daily return of market index and target equity with `scipy.stats`
